# %%
import matplotlib.pyplot as plt

# %%
gpus = [1, 2, 3, 4]
batches = [128, 256, 512]
one = [2674.47, 2417.13, 2218.39, 2329.82]
two = [2461.46, 2360.52, 2028.72, 2350.78]
three = [2500.82, 2306.56, 2296.49, 2335.14]
gpu0_512 = [7.403, 3.219, 3.633, 3.035]
gpu0_256 = [2.859, 2.921, 1.809, 1.649]
gpu0_128 = [2.859, 1.569, 1.419, 1.355]
plt.figure(figsize=(8, 7))
plt.plot(gpus, one, '-ok', color="blue", label="512 batches")
plt.plot(gpus, two, '-ok', color="green", label="256 batches")
plt.plot(gpus, three, '-ok', color="red", label="128 batches")
plt.xlabel("Num of GPUs")
plt.ylabel("Memory consumed")
plt.title("Execution time on each GPU")
plt.legend()
plt.savefig("gpus_vs_time.png")

# %%
gpus = [1,2,3]
gpu3_512 = [3.633, 3.497, 3.477]
gpu3_256 = [1.809, 1.739, 1.719]
gpu3_128 = [1.419, 1.381, 1.373]
plt.figure(figsize=(8, 7))
plt.plot(gpus, gpu3_512, '-ok', color="blue", label="512 batches")
plt.plot(gpus, gpu3_256, '-ok', color="green", label="256 batches")
plt.plot(gpus, gpu3_128, '-ok', color="red", label="128 batches")
plt.xlabel("Num of GPUs")
plt.ylabel("Memory consumed")
plt.title("Data Parallel using 3 GPUs")
plt.legend()
plt.savefig("gpus_vs_memory2.png")

# %%
gpus = [1]
gpu4_512 = [7.403]
gpu4_256 = [2.860]
gpu4_128 = [2.859]
plt.figure(figsize=(8, 7))
plt.plot(gpus, gpu4_512, '-ok', color="blue", label="512 batches")
plt.plot(gpus, gpu4_256, '-ok', color="green", label="256 batches")
plt.plot(gpus, gpu4_128, '-ok', color="red", label="128 batches")
plt.xlabel("GPUs")
plt.ylabel("Memory consumed / GPU (GB)")
plt.title("Memory consumption profile on 1 GPUs")
plt.legend()
plt.savefig("gpus_vs_memory_1.png")

# %%
batches = [128, 256, 512]
acc_1 = [99.91, 99.87, 98.93]
acc_2 = [99.95, 99.88, 99.77]
acc_3 = [99.90, 99.82, 99.67]
acc_4 = [99.88, 99.78, 99.53]
plt.figure(figsize=(8, 7))
plt.plot(batches, acc_1, '-ok', color="blue", label="1 GPU")
plt.plot(batches, acc_2, '-ok', color="green", label="2 GPUs")
plt.plot(batches, acc_3, '-ok', color="red", label="3 GPUs")
plt.plot(batches, acc_4, '-ok', color="black", label="4 GPUs")
plt.xlabel("Batches")
plt.ylabel("Validation accuracy (%)")
plt.title("Validation accuracy for different batches")
plt.legend()
plt.savefig("batches_vs_accuracy.png")

# %%
batches = [128, 256, 512]
time_1 = [2500.82, 2461.46, 2674.47]
time_2 = [2306.56, 2360.52, 2417.13]
time_3 = [2296.49, 2028.72, 2218.39]
time_4 = [2335.14, 2350.78, 2329.82]
plt.figure(figsize=(8, 7))
plt.plot(batches, time_1, '-ok', color="blue", label="1 GPU")
plt.plot(batches, time_2, '-ok', color="green", label="2 GPUs")
plt.plot(batches, time_3, '-ok', color="red", label="3 GPUs")
plt.plot(batches, time_4, '-ok', color="black", label="4 GPUs")
plt.xlabel("Batches")
plt.ylabel("Execution time (secs)")
plt.title("Execution time taken for different batches for each GPU")
plt.legend()
plt.savefig("batches_vs_execTime.png")

# %%
batches = [128, 256, 512]
time_1 = [2500.82, 2461.46, 2674.47]
time_2 = [2306.56, 2360.52, 2417.13]
time_3 = [2296.49, 2028.72, 2218.39]
time_4 = [2335.14, 2350.78, 2329.82]
